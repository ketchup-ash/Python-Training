# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('data/bikes.csv',
            encoding='latin1',
            sep=';',
            parse_dates=['Date'],
            index_col='Date'
           )

# %%
df[['Berri 1','Rachel1']]
# Out:
#             Berri 1  Rachel1
# Date
# 2012-01-01       35       16
# 2012-02-01       83       43
# 2012-03-01      135       58
# 2012-04-01      144       61
# 2012-05-01      197       95
# 2012-06-01      146       75
# 2012-07-01       98       54
# 2012-08-01       95       63
# 2012-09-01      244      173
# 2012-10-01      397      241
# 2012-11-01      273      194
# 2012-12-01      157       63
# 2012-01-13       75        0
# 2012-01-14       32        1
# 2012-01-15       54        0
# 2012-01-16      168        0
# 2012-01-17      155        0
# 2012-01-18      139        0
# 2012-01-19      191        0
# 2012-01-20      161        1
# 2012-01-21       53        0
# 2012-01-22       71        0
# 2012-01-23      210        0
# 2012-01-24      299        0
# 2012-01-25      334        0
# 2012-01-26      306        1
# 2012-01-27       91        0
# 2012-01-28       80        1
# 2012-01-29       87        0
# 2012-01-30      219        0
# ...             ...      ...
# ...

# %%
df.head()
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-02-01       83                                NaN                      1
# 2012-03-01      135                                NaN                      2
# 2012-04-01      144                                NaN                      1
# 2012-05-01      197                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-01             38             51       26            10       16
# 2012-02-01             68            153       53             6       43
# 2012-03-01            104            248       89             3       58
# 2012-04-01            116            318      111             8       61
# 2012-05-01            124            330       97            13       95
#
# ...

# %%
df.tail()
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-11     2405                                NaN                   1208
# 2012-02-11     1582                                NaN                    737
# 2012-03-11      844                                NaN                    380
# 2012-04-11      966                                NaN                    446
# 2012-05-11     2247                                NaN                   1170
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-11           1701           3082     2076           165     2461
# 2012-02-11           1109           2277     1392            97     1888
# 2012-03-11            612           1137      713           105     1302
# 2012-04-11            710           1277      692           197     1374
# 2012-05-11           1705           3221     2143           179     2430
#
# ...

# %%
df[50:150]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-02-20      303                                NaN                      2
# 2012-02-21      441                                NaN                      5
# 2012-02-22      375                                NaN                     10
# 2012-02-23      397                                NaN                     10
# 2012-02-24      243                                NaN                      4
# 2012-02-25       62                                NaN                      0
# 2012-02-26       78                                NaN                      0
# 2012-02-27      119                                NaN                      4
# 2012-02-28      195                                NaN                      0
# 2012-02-29      242                                NaN                      0
# 2012-01-03       92                                NaN                      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 310 entries, 2012-01-01 to 2012-05-11
# Data columns (total 9 columns):
# Berri 1                                310 non-null int64
# Brébeuf (données non disponibles)      0 non-null float64
# Côte-Sainte-Catherine                  310 non-null int64
# Maisonneuve 1                          310 non-null int64
# Maisonneuve 2                          310 non-null int64
# du Parc                                310 non-null int64
# Pierre-Dupuy                           310 non-null int64
# Rachel1                                310 non-null int64
# St-Urbain (données non disponibles)    0 non-null float64
# dtypes: float64(2), int64(7)
# memory usage: 24.2 KB

# %%
df.columns
# Out:
# Index(['Berri 1', 'Brébeuf (données non disponibles)', 'Côte-Sainte-Catherine',
#        'Maisonneuve 1', 'Maisonneuve 2', 'du Parc', 'Pierre-Dupuy', 'Rachel1',
#        'St-Urbain (données non disponibles)'],
#       dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01',
#                '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01',
#                '2012-09-01', '2012-10-01',
#                ...
#                '2012-10-27', '2012-10-28', '2012-10-29', '2012-10-30',
#                '2012-10-31', '2012-01-11', '2012-02-11', '2012-03-11',
#                '2012-04-11', '2012-05-11'],
#               dtype='datetime64[ns]', name='Date', length=310, freq=None)

# %%
plt.figure(figsize=(12,5))
plt.title("Plot showing number of cylist on Berri 1 over the year")
df['Berri 1'].plot()
plt.show()

# %%
df[['Berri 1','Maisonneuve 1','Rachel1']].plot()

# %%
df['Berri 1'].sum()
# Out:
# 925365

# %%
df.sum().plot(kind='bar')
plt.show()

# %%
complaints = pd.read_csv('data/311-service-requests.csv',
                         parse_dates=['Created Date','Closed Date'],
                        index_col='Created Date')
complaints.head()
# Out:
# /home/asit/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                      Unique Key         Closed Date Agency  \
# Created Date
# 2013-10-31 02:08:41    26589651                 NaT   NYPD
# 2013-10-31 02:01:04    26593698                 NaT   NYPD
# 2013-10-31 02:00:24    26594139 2013-10-31 02:40:32   NYPD
# 2013-10-31 01:56:23    26595721 2013-10-31 02:21:48   NYPD
# 2013-10-31 01:53:44    26590930                 NaT  DOHMH
#
#                                                  Agency Name  \
# Created Date
# 2013-10-31 02:08:41          New York City Police Department
# 2013-10-31 02:01:04          New York City Police Department
# 2013-10-31 02:00:24          New York City Police Department
# 2013-10-31 01:56:23          New York City Police Department
# ...

# %%
complaints.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 111069 entries, 2013-10-31 02:08:41 to 2013-10-04 00:00:10
# Data columns (total 51 columns):
# Unique Key                        111069 non-null int64
# Closed Date                       60270 non-null datetime64[ns]
# Agency                            111069 non-null object
# Agency Name                       111069 non-null object
# Complaint Type                    111069 non-null object
# Descriptor                        110613 non-null object
# Location Type                     79022 non-null object
# Incident Zip                      98807 non-null object
# Incident Address                  84441 non-null object
# Street Name                       84432 non-null object
# Cross Street 1                    84728 non-null object
# Cross Street 2                    84005 non-null object
# Intersection Street 1             19364 non-null object
# Intersection Street 2             19366 non-null object
# ...

# %%
complaints['Complaint Type']
# Out:
# Created Date
# 2013-10-31 02:08:41     Noise - Street/Sidewalk
# 2013-10-31 02:01:04             Illegal Parking
# 2013-10-31 02:00:24          Noise - Commercial
# 2013-10-31 01:56:23             Noise - Vehicle
# 2013-10-31 01:53:44                      Rodent
# 2013-10-31 01:46:52          Noise - Commercial
# 2013-10-31 01:46:40            Blocked Driveway
# 2013-10-31 01:44:19          Noise - Commercial
# 2013-10-31 01:44:14          Noise - Commercial
# 2013-10-31 01:34:41          Noise - Commercial
# 2013-10-31 01:25:12    Noise - House of Worship
# 2013-10-31 01:24:14          Noise - Commercial
# 2013-10-31 01:20:57             Illegal Parking
# 2013-10-31 01:20:13             Noise - Vehicle
# 2013-10-31 01:19:54                      Rodent
# 2013-10-31 01:14:02    Noise - House of Worship
# 2013-10-31 00:54:03     Noise - Street/Sidewalk
# 2013-10-31 00:52:46             Illegal Parking
# 2013-10-31 00:51:00      Street Light Condition
# ...

# %%
complaints['Complaint Type'].value_counts().head(10).plot(kind='bar')

# %%
complaints['Borough'].value_counts().head(10).plot(kind='bar')

# %%
complaints['Borough'].value_counts().head(10).plot(kind='bar')
plt.show()
complaints['Complaint Type'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
cols=['Complaint Type','Descriptor','Location Type','Borough']
df = complaints[cols] 
df.head()
# Out:
#                               Complaint Type                    Descriptor  \
# Created Date
# 2013-10-31 02:08:41  Noise - Street/Sidewalk                  Loud Talking
# 2013-10-31 02:01:04          Illegal Parking  Commercial Overnight Parking
# 2013-10-31 02:00:24       Noise - Commercial              Loud Music/Party
# 2013-10-31 01:56:23          Noise - Vehicle                Car/Truck Horn
# 2013-10-31 01:53:44                   Rodent  Condition Attracting Rodents
#
#                            Location Type    Borough
# Created Date
# 2013-10-31 02:08:41      Street/Sidewalk     QUEENS
# 2013-10-31 02:01:04      Street/Sidewalk     QUEENS
# 2013-10-31 02:00:24  Club/Bar/Restaurant  MANHATTAN
# 2013-10-31 01:56:23      Street/Sidewalk  MANHATTAN
# 2013-10-31 01:53:44           Vacant Lot  MANHATTAN
